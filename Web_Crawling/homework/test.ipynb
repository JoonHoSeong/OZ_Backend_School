# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

user = "Mozilla/5.0 (IPhone; CPU iPhone OS 13_3 like Mac OS X) AppleWebKit/605.1.15(KHTML, like Gecko) CriOS/80.0.3987.95 Mobile/15E148 Safari/604.1"

options_ = Options()
options_.add_argument(f"user-agent={user}")
options_.add_experimental_option("detach", True)

# options_.add_experimental_option("excludeSwitches", ["enable-logging"])


#크롬 드라이버 매니저를 자동으로 설치되도록 실행시키는 코드
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options_)

url = "https://m2.melon.com/index.htm"
driver.get(url)
time.sleep(0.5)

def check_and_pass_event_page() :
    # #이벤트 페이지 넘어가기
    # 이벤트 페이지면 호출
    try : 
        driver.find_element(By.CLASS_NAME, 'ir-pm')
        print('Delete AD')
        driver.find_element(By.XPATH, '/html/body/div[2]/header/h1/a/img').click() #멜론 로고 클릭
        
    except :
        pass
    
check_and_pass_event_page()

def scroll_down_inf() :
    check_and_pass_event_page()
    time.sleep(1)
    #끝까지 스크롤 하기
    prev_height = -1
    max_scrolls = 100
    scroll_count = 0
    while scroll_count < max_scrolls:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)  # give some time for new results to load
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == prev_height:
            break
        prev_height = new_height
        scroll_count += 1
    time.sleep(1)
    check_and_pass_event_page()
    
    
driver.find_element(By.XPATH, '//*[@id="naviMenu"]/nav/ul/li[3]/a').click()#차트 항목 클릭
scroll_down_inf()# 끝까지 스크롤 내리기

driver.find_element(By.XPATH,'/html/body/div[1]/div/div/article[3]/button').click() # 더보기 클릭

scroll_down_inf()#끝까지 스크롤 내리기
    

#아래 순서대로 스크래핑한 자료를 출력해주세요
#순위 :
#노래 제목 :
#가수 이름 :
for i in driver.find_element(By.ID, '_chartList').find_elements(By.CLASS_NAME,'list_item') :
    print('순위 : ',i.find_element(By.CLASS_NAME, 'ranking_num').text.split('\n')[0])
    print('노래 제목 : ',i.find_element(By.CLASS_NAME,'content').text.split('\n')[0])
    print('가수 이름 : ',i.find_element(By.CLASS_NAME,'content').text.split('\n')[1])






# driver.quit()
# Out:
# Delete AD
# 순위 :  1
# 노래 제목 :  Supernova
# 가수 이름 :  aespa
# 순위 :  2
# 노래 제목 :  SPOT! (feat. JENNIE)
# 가수 이름 :  지코 (ZICO)
# 순위 :  3
# 노래 제목 :  해야 (HEYA)
# 가수 이름 :  IVE (아이브)
# 순위 :  4
# 노래 제목 :  Magnetic
# 가수 이름 :  아일릿(ILLIT)
# 순위 :  5
# 노래 제목 :  고민중독
# 가수 이름 :  QWER
# 순위 :  6
# 노래 제목 :  나는 아픈 건 딱 질색이니까
# 가수 이름 :  (여자)아이들
# 순위 :  7
# 노래 제목 :  How Sweet
# 가수 이름 :  NewJeans
# 순위 :  8
# 노래 제목 :  소나기
# 가수 이름 :  이클립스 (ECLIPSE)
# 순위 :  9
# 노래 제목 :  미안해 미워해 사랑해
# 가수 이름 :  Crush
# 순위 :  10
# 노래 제목 :  첫 만남은 계획대로 되지 않아
# 가수 이름 :  TWS (투어스)
# 순위 :  11
# 노래 제목 :  천상연
# 가수 이름 :  이창섭
# 순위 :  12
# 노래 제목 :  SHEESH
# 가수 이름 :  BABYMONSTER
# 순위 :  13
# 노래 제목 :  한 페이지가 될 수 있게
# 가수 이름 :  DAY6 (데이식스)
# 순위 :  14
# 노래 제목 :  Bubble Gum
# 가수 이름 :  NewJeans
# 순위 :  15
# 노래 제목 :  예뻤어
# 가수 이름 :  DAY6 (데이식스)
# 순위 :  16
# 노래 제목 :  Love wins all
# 가수 이름 :  아이유
# 순위 :  17
# 노래 제목 :  밤양갱
# 가수 이름 :  비비 (BIBI)
# 순위 :  18
# 노래 제목 :  비의 랩소디
# 가수 이름 :  임재현
# 순위 :  19
# 노래 제목 :  에피소드
# 가수 이름 :  이무진
# 순위 :  20
# 노래 제목 :  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# 가수 이름 :  너드커넥션 (Nerd Connection)
# 순위 :  21
# 노래 제목 :  To. X
# 가수 이름 :  태연 (TAEYEON)
# 순위 :  22
# 노래 제목 :  Hype Boy
# 가수 이름 :  NewJeans
# 순위 :  23
# 노래 제목 :  MAESTRO
# 가수 이름 :  세븐틴 (SEVENTEEN)
# 순위 :  24
# 노래 제목 :  Drama
# 가수 이름 :  aespa
# 순위 :  25
# 노래 제목 :  I AM
# 가수 이름 :  IVE (아이브)
# 순위 :  26
# 노래 제목 :  헤어지자 말해요
# 가수 이름 :  박재정
# 순위 :  27
# 노래 제목 :  Welcome to the Show
# 가수 이름 :  DAY6 (데이식스)
# 순위 :  28
# 노래 제목 :  EASY
# 가수 이름 :  LE SSERAFIM (르세라핌)
# 순위 :  29
# 노래 제목 :  Smart
# 가수 이름 :  LE SSERAFIM (르세라핌)
# 순위 :  30
# 노래 제목 :  ETA
# 가수 이름 :  NewJeans
# 순위 :  31
# 노래 제목 :  사랑인가 봐
# 가수 이름 :  멜로망스
# 순위 :  32
# 노래 제목 :  Seven (feat. Latto) - Clean Ver.
# 가수 이름 :  정국
# 순위 :  33
# 노래 제목 :  Super Shy
# 가수 이름 :  NewJeans
# 순위 :  34
# 노래 제목 :  사랑은 늘 도망가
# 가수 이름 :  임영웅
# 순위 :  35
# 노래 제목 :  인사
# 가수 이름 :  범진
# 순위 :  36
# 노래 제목 :  Ditto
# 가수 이름 :  NewJeans
# 순위 :  37
# 노래 제목 :  Perfect Night
# 가수 이름 :  LE SSERAFIM (르세라핌)
# 순위 :  38
# 노래 제목 :  너의 모든 순간
# 가수 이름 :  성시경
# 순위 :  39
# 노래 제목 :  Spicy
# 가수 이름 :  aespa
# 순위 :  40
# 노래 제목 :  Love 119
# 가수 이름 :  RIIZE
# 순위 :  41
# 노래 제목 :  Midas Touch
# 가수 이름 :  KISS OF LIFE
# 순위 :  42
# 노래 제목 :  Lucky Girl Syndrome
# 가수 이름 :  아일릿(ILLIT)
# 순위 :  43
# 노래 제목 :  MANIAC
# 가수 이름 :  VIVIZ (비비지)
# 순위 :  44
# 노래 제목 :  그랬나봐
# 가수 이름 :  유회승 (엔플라잉)
# 순위 :  45
# 노래 제목 :  슬픈 초대장
# 가수 이름 :  순순희 (지환)
# 순위 :  46
# 노래 제목 :  사막에서 꽃을 피우듯
# 가수 이름 :  우디 (Woody)
# 순위 :  47
# 노래 제목 :  Love Lee
# 가수 이름 :  AKMU (악뮤)
# 순위 :  48
# 노래 제목 :  홀씨
# 가수 이름 :  아이유
# 순위 :  49
# 노래 제목 :  퀸카 (Queencard)
# 가수 이름 :  (여자)아이들
# 순위 :  50
# 노래 제목 :  Attention
# 가수 이름 :  NewJeans
# 순위 :  51
# 노래 제목 :  OMG
# 가수 이름 :  NewJeans
# 순위 :  52
# 노래 제목 :  꿈
# 가수 이름 :  태연 (TAEYEON)
# 순위 :  53
# 노래 제목 :  파이팅 해야지 (Feat. 이영지)
# 가수 이름 :  부석순 (SEVENTEEN)
# 순위 :  54
# 노래 제목 :  주저하는 연인들을 위해
# 가수 이름 :  잔나비
# 순위 :  55
# 노래 제목 :  사건의 지평선
# 가수 이름 :  윤하 (YOUNHA)
# 순위 :  56
# 노래 제목 :  LOVE DIVE
# 가수 이름 :  IVE (아이브)
# 순위 :  57
# 노래 제목 :  Get A Guitar
# 가수 이름 :  RIIZE
# 순위 :  58
# 노래 제목 :  모든 날, 모든 순간 (Every day, Every Moment)
# 가수 이름 :  폴킴
# 순위 :  59
# 노래 제목 :  취중고백
# 가수 이름 :  김민석
# 순위 :  60
# 노래 제목 :  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 가수 이름 :  AKMU (악뮤)
# 순위 :  61
# 노래 제목 :  우리들의 블루스
# 가수 이름 :  임영웅
# 순위 :  62
# 노래 제목 :  손오공
# 가수 이름 :  세븐틴 (SEVENTEEN)
# 순위 :  63
# 노래 제목 :  I Don't Think That I Like Her
# 가수 이름 :  Charlie Puth
# 순위 :  64
# 노래 제목 :  Accendio
# 가수 이름 :  IVE (아이브)
# 순위 :  65
# 노래 제목 :  잘 지내자, 우리 (여름날 우리 X 로이킴)
# 가수 이름 :  로이킴
# 순위 :  66
# 노래 제목 :  봄눈
# 가수 이름 :  10CM
# 순위 :  67
# 노래 제목 :  다정히 내 이름을 부르면
# 가수 이름 :  경서예지,전건호
# 순위 :  68
# 노래 제목 :  You & Me
# 가수 이름 :  제니 (JENNIE)
# 순위 :  69
# 노래 제목 :  그대가 내 안에 박혔다(그내박)
# 가수 이름 :  순순희(기태)
# 순위 :  70
# 노래 제목 :  Girls Never Die
# 가수 이름 :  tripleS (트리플에스)
# 순위 :  71
# 노래 제목 :  사랑하지 않아서 그랬어
# 가수 이름 :  임한별
# 순위 :  72
# 노래 제목 :  Baddie
# 가수 이름 :  IVE (아이브)
# 순위 :  73
# 노래 제목 :  심(心)
# 가수 이름 :  DK(디셈버)
# 순위 :  74
# 노래 제목 :  청혼하지 않을 이유를 못 찾았어
# 가수 이름 :  이무진
# 순위 :  75
# 노래 제목 :  Impossible
# 가수 이름 :  RIIZE
# 순위 :  76
# 노래 제목 :  봄날
# 가수 이름 :  방탄소년단
# 순위 :  77
# 노래 제목 :  Dynamite
# 가수 이름 :  방탄소년단
# 순위 :  78
# 노래 제목 :  Siren
# 가수 이름 :  RIIZE
# 순위 :  79
# 노래 제목 :  Kitsch
# 가수 이름 :  IVE (아이브)
# 순위 :  80
# 노래 제목 :  Super Lady
# 가수 이름 :  (여자)아이들
# 순위 :  81
# 노래 제목 :  모래 알갱이
# 가수 이름 :  임영웅
# 순위 :  82
# 노래 제목 :  청춘찬가
# 가수 이름 :  세븐틴 (SEVENTEEN)
# 순위 :  83
# 노래 제목 :  혹시 세상에 혼자 남겨진 것 같다면
# 가수 이름 :  우디 (Woody)
# 순위 :  84
# 노래 제목 :  멈춰줘
# 가수 이름 :  헤이즈 (Heize)
# 순위 :  85
# 노래 제목 :  다시 만날 수 있을까
# 가수 이름 :  임영웅
# 순위 :  86
# 노래 제목 :  후라이의 꿈
# 가수 이름 :  AKMU (악뮤)
# 순위 :  87
# 노래 제목 :  온기
# 가수 이름 :  임영웅
# 순위 :  88
# 노래 제목 :  이제 나만 믿어요
# 가수 이름 :  임영웅
# 순위 :  89
# 노래 제목 :  WAY 4 LUV
# 가수 이름 :  PLAVE
# 순위 :  90
# 노래 제목 :  Do or Die
# 가수 이름 :  임영웅
# 순위 :  91
# 노래 제목 :  무지개
# 가수 이름 :  임영웅
# 순위 :  92
# 노래 제목 :  Run Run
# 가수 이름 :  이클립스 (ECLIPSE)
# 순위 :  93
# 노래 제목 :  음악의 신
# 가수 이름 :  세븐틴 (SEVENTEEN)
# 순위 :  94
# 노래 제목 :  London Boy
# 가수 이름 :  임영웅
# 순위 :  95
# 노래 제목 :  Home
# 가수 이름 :  임영웅
# 순위 :  96
# 노래 제목 :  꿈결같아서
# 가수 이름 :  민니 ((여자)아이들)
# 순위 :  97
# 노래 제목 :  Steal The Show (From "Elemental")
# 가수 이름 :  Lauv
# 순위 :  98
# 노래 제목 :  Polaroid
# 가수 이름 :  임영웅
# 순위 :  99
# 노래 제목 :  좋아해요
# 가수 이름 :  폴킴
# 순위 :  100
# 노래 제목 :  해요 (2022)
# 가수 이름 :  #안녕
