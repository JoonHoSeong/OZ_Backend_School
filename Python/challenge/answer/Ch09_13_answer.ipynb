# %% [markdown]
# ### 1. movie_rank 리스트에는 아래와 같이 네 개의 영화 제목이 바인딩되어 있다. "비밀"을 "나폴레옹"과 "괴물" 사이에 추가하라.
#
# <aside>
# 🔑 정답 : **movie.insert(2, '비밀')**
#
# Python 리스트에서 특정 위치에 값을 추가하려면 `insert()` 메소드를 사용할 수 있습니다.
# `insert()` 메소드는 첫 번째 인자로 삽입할 위치의 인덱스를, 두 번째 인자로 삽입할 값을 받습니다.
#
# "비밀"을 "나폴레옹"과 "괴물" 사이에 추가하는 코드는 아래와 같습니다.
#
# ```python
# movie.insert(2, '비밀')
# ```
#
# 위 코드에서 `2`는 "비밀"이 추가될 위치의 인덱스이며, 파이썬에서 리스트의 인덱스는 0부터 시작하기 때문에 "나폴레옹"(인덱스 1) 다음에 "비밀"을 추가하기 위해 `2`를 사용합니다. `'비밀'`은 추가할 값입니다.
#
# 이렇게 하면 `movie` 리스트는 `['서울의 봄', '나폴레옹', '비밀', '괴물', '베트맨']`과 같이 "비밀"이 "나폴레옹"과 "괴물" 사이에 추가됩니다.
#
# </aside>
#
# ---
#
# ### 2. **movie_rank 리스트에서 '베트맨'를 삭제하라.**
#
# <aside>
# 🔑 정답 : **movie.remove(’베트맨’)**
#
# Python 리스트에서 특정 값을 삭제하려면 `remove()` 함수를 사용할 수 있습니다. `remove()` 함수는 리스트에서 첫 번째로 나타나는 특정 값을 제거합니다.
#
# 따라서 '베트맨'을 삭제하려면 다음과 같이 코드를 작성할 수 있습니다.
#
# ```python
# movie.remove('베트맨')
# ```
#
# 이 코드는 `movie` 리스트에서 '베트맨'이라는 값을 찾아 제거합니다.
# 이렇게 하면 `movie` 리스트는 `['서울의 봄', '나폴레옹', '비밀', '괴물']`이 됩니다.
#
# 단, `remove()` 함수는 리스트에서 해당 값이 없을 경우 ValueError를 발생시키므로, 해당 값이 리스트에 있는지 확인한 후 삭제하는 것이 안전합니다.
#
# </aside>
#
# ---
#
# ### 3. [언어1]과 [언어2] 리스트가 있을 때 언어1과 언어2의 원소를 모두 갖고 있는 [언어모음]이라는 list를 만들어주세요
#
# - lang1 = ["C", "C++", "JAVA"]
# - lang2 = ["Python", "Go", "C#"]
#
# <aside>
# 🔑 정답 : **lang1+lang2, lang1.extend(lang2)**
#
# Python에서는 '+' 연산자를 사용하여 두 개의 리스트를 합칠 수 있습니다.
#
# ```python
# lang1 = ["C", "C++", "JAVA"]
# lang2 = ["Python", "Go", "C#"]
#
# langs = lang1 + lang2
# ```
#
# 이 코드에서, `lang1`과 `lang2` 두 리스트가 '+' 연산자를 통해 하나의 리스트로 합쳐졌습니다. 이렇게 만들어진 `langs` 리스트는 `["C", "C++", "JAVA", "Python", "Go", "C#"]` 이렇게 됩니다.
#
# 이 방법 외에도 `extend()` 함수를 사용해서도 두 리스트를 합칠 수 있습니다.
#
# ```python
# lang1 = ["C", "C++", "JAVA"]
# lang2 = ["Python", "Go", "C#"]
#
# lang1.extend(lang2)
# ```
#
# `extend()` 함수는 리스트의 끝에 다른 리스트의 모든 항목을 추가합니다. 따라서 이 코드를 실행하면 `lang1` 리스트는 `["C", "C++", "JAVA", "Python", "Go", "C#"]` 이렇게 변하게 됩니다.
#
# </aside>
#
# ---
#
# ### 4. **다음 리스트에서 최댓값과 최솟값을 출력해주세요.**
#
# nums = [1, 2, 3, 4, 5, 6, 7, 9, 10]
#
# <aside>
# 🔑 정답 : **max(nums) / min(nums)**
#
# Python에서는 `max()` 함수와 `min()` 함수를 사용하여 리스트의 최댓값과 최솟값을 구할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 5. **다음 리스트에 저장된 데이터의 개수를 화면에 구해주세요**
#
# cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면"]
#
# <aside>
# 🔑 정답 : **len(cook)**
#
# 파이썬에서는 `len()` 함수를 사용하여 리스트에 저장된 데이터의 개수를 구할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 6. **다음 리스트의 평균을 출력해주세요**
#
# nums = [1, 2, 3, 4, 5]
#
# <aside>
# 🔑 정답 : **sum(nums) / len(nums)**
#
# `sum(nums) / len(nums)`는 `nums` 리스트의 모든 항목의 합계를 항목의 개수로 나눈 값, 즉 평균을 구합니다.
#
# </aside>
#
# ---
#
# ### 7. **price 변수에는 날짜와 종가 정보가 저장돼 있습니다. 날짜 정보를 제외하고 가격 정보만을 출력해주세요**
#
# price=[’20180728’, 100, 130, 140, 150, 160, 170]
#
# <aside>
# 🔑 정답 : **price[1:0]**
#
# **`price[1:]`는 `price` 리스트의 첫 번째 인덱스부터 끝까지의 값을 선택합니다.**
#
# **따라서 이 코드는 '20180728'을 제외한 나머지 값을 가지는 새로운 리스트 `new_price`를 만듭니다. 이렇게 슬라이싱을 사용하면 리스트의 특정 범위의 값을 쉽게 선택할 수 있습니다.**
#
# </aside>
#
# ---
#
# ### 8. **아래 코드 실행 시 오류가 발생한 사유를 설명해주세요**
#
# **t = (1, 2, 3)
# t[0] = 'a'
# Traceback (most recent call last):
# File "<pyshell#46>", line 1, in
# t[0] = 'a'
# TypeError: 'tuple' object does not support item assignment**
#
# <aside>
# 🔑 정답 :
#
# 코드에서 `t`는 튜플(tuple)입니다. 튜플은 불변(immutable)한 자료형이므로, 한 번 생성된 튜플의 요소는 변경할 수 없습니다. 따라서 튜플의 요소에 대한 재할당은 파이썬에서 허용되지 않습니다.
# 코드에서 `t[0] = 'a'`라는 표현은 튜플 `t`의 첫 번째 요소를 'a'로 변경하려는 시도입니다.
#
# 하지만 이는 튜플의 불변성에 위배되므로, 파이썬은 `TypeError: 'tuple' object does not support item assignment`이라는 오류 메시지를 출력합니다.
#
# 이를 해결하려면, 튜플 대신 변경 가능한 자료형(예: 리스트)를 사용하거나, 필요한 변경을 반영한 새로운 튜플을 생성해야 합니다.
#
# </aside>
#
# ---
#
# ### 9. 다음 딕셔너리를 사용하여 메로나 가격을 출력해주세요
#
# <aside>
# 🔑 정답 : **print(”메로나의 가격:  “, ice[’메로나’] )**
#
# `ice['메로나']`는 딕셔너리 `ice`에서 '메로나'라는 키에 해당하는 값을 반환합니다. 이렇게 반환된 값은 "메로나의 가격: "라는 문자열과 함께 출력됩니다.
#
# 따라서 이 코드는 딕셔너리 `ice`에서 '메로나'의 가격을 출력하는 코드입니다. 이렇게 딕셔너리를 사용하면 키와 값을 쌍으로 저장하여 효율적으로 사용할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 10. 다음 딕셔너리에서 메로나의 가격을 1300으로 수정해주세요
#
# <aside>
# 🔑 정답 : **ice[’메로나’] = 1300**
#
# `ice['메로나'] = 1300`은 딕셔너리 `ice`에서 '메로나'라는 키에 해당하는 값을 1300으로 변경합니다. 이렇게 변경된 딕셔너리는 "수정된 딕셔너리: "라는 문자열과 함께 출력됩니다.
#
# 따라서 이 코드는 딕셔너리 `ice`에서 '메로나'의 가격을 1300으로 수정하는 코드입니다. 이렇게 딕셔너리를 사용하면 키와 값을 쌍으로 저장하여 효율적으로 사용할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 11. 아래 순서대로 주어진 수강생 이름과 등급을 하나의 딕셔너리로 만드는 코드를 작성해주세요
#
# <aside>
# 🔑 정답 : **dict(zip(names, grades))**
#
# `zip()` 함수는 `names`와 `grades` 리스트를 한 쌍으로 묶어줍니다. 즉, `zip(names, grades)`는 [("나이썬", "B"), ("김자바", "B"), ("김씨", "A"), ("박씨샵", "C")]와 같은 형태의 값을 반환합니다. `dict()` 함수는 이 값을 딕셔너리로 변환합니다.
#
# 따라서 이 코드는 주어진 이름과 등급을 딕셔너리로 만드는 코드입니다. 이렇게 딕셔너리를 사용하면 키와 값을 쌍으로 저장하여 효율적으로 사용할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 12. **아래 ice 딕셔너리에 데이터를 추가 후 출력해주세요**
#
# <aside>
# 🔑 정답 : **ice[”보석바”] = [300, 20]**
#
# `ice["보석바"] = [650, 10]`은 딕셔너리 `ice`에 '보석바'라는 새로운 키와 `[650, 10]`이라는 새로운 값을 추가합니다. 이렇게 추가된 딕셔너리는 "수정된 딕셔너리: "라는 문자열과 함께 출력됩니다.
#
# 따라서 이 코드는 딕셔너리 `ice`에 '보석바'라는 키와 그에 해당하는 값을 추가하는 코드입니다. 이렇게 딕셔너리를 사용하면 키와 값을 쌍으로 저장하여 효율적으로 사용할 수 있습니다.
#
# </aside>
#
# ---
#
# ### 13. **아래 딕셔너리에서 key만 출력해주세요**
#
# <aside>
# 🔑 정답 : **ice.keys()**
#
# `ice.keys()`는 딕셔너리 `ice`의 모든 키를 반환합니다. `list()` 함수를 사용하여 이를 리스트로 변환한 후, "키만 추출: "라는 문자열과 함께 출력합니다.
#
# 따라서 이 코드는 딕셔너리 `ice`에서 키만 추출하는 코드입니다. 이렇게 `keys()` 메서드를 사용하면 딕셔너리의 키를 쉽게 추출할 수 있습니다.
#
# </aside>
#
# ---
