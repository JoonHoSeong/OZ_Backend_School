# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~! Chapter05 ~ 08 수업은 잘 들으셨나요?
#
# Chapter05 ~ 08의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후 ▷ 버튼을 클릭해 코드를 실행해보세요<br>

# %% [markdown]
# -----

# %% [markdown]
# [문제1]
#
# 변수명 게임에 들어 있는 값 중 '홀'만 출력되도록 코드를 작성해 주세요
#
# 게임 = "홀짝홀짝홀짝"
#
# 출력 예시 : "홀홀홀"

# %%
game = '홀짝홀짝홀짝'
print(game[::2])
# Out:
# 홀홀홀

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# 변수명 전화번호에 들어 있는 번호를 모두 붙여서 출력되도록 코드를 작성해주세요
#
# 전화번호 = "010-1234-5678"
#
# 출력 예시 : "01012345678"

# %%
phone_number = '010-1234-5678'
print(''.join(phone_number.split('-')))
# Out:
# 01012345678

# %% [markdown]
# ----

# %% [markdown]
# [문제3]
#
# 창의성, 시장성, 안정성, 수익성에 대한 각각의 평가 중 아래 기준에 부합하지 못하면 창업지원을 받을 수 없습니다.
#
# - 수익성 60점 이상
# - 창의성과 시장성 50점 이상
# - 시장성과 수익성을 더한 값의 절반이 안정성 보다 높아야 함
#
# 다음 점수가 입력되었을때 창업 지원이 가능한지 여부를 True 또는 False로 출력해주세요
#
# ---
#
# 창의성 : 62
# 시장성 : 71
# 안정성 : 68
# 수익성 : 66

# %%
creativity = 62
profitability = 62
marketability = 71
stability = 66

print(creativity>60 and creativity >50 and marketability > 50 and (profitability+marketability)/2 > stability)
# Out:
# True
