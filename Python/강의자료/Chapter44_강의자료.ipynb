# %% [markdown]
# 안녕하세요
#
# 수강생 여러분
#
# 오늘도 저와 함께 달릴 준비 되셨나요?
#
# 그럼 인스턴스와 특수 메소드에 대한 강의를 시작하겠습니다.

# %% [markdown]
# 클래스로 부터 생성된 객체를 인스턴스라고 했습니다.
#
# 우리는 하나의 클래스를 선언헀지만 규모가 커지면 다양한 클래스가 존재할 수 있습니다.
#
# 이럴경우 어떤 클래스에서 생성된 인스턴스(객체)인지 확인하기 어려울 때가 있습니다.
#
# 또한, 어떤 클래스에서 생성된 인스터스인지에 따라 다른 방식으로 대처해야할 때가 있을 겁니다.
#
# 이럴때 어떤 클래스에서 생성된 객체인지에 대한 정보를 확인할 수 있는 isinstance() 함수를 이용할 수 있습니다.
#
# - isinstance() : 첫 번째 매개변수에는 인스턴스(객체), 두 번째 매개변수에는 클래스를 입력해주면<br>
# 두번째 매개변수로 입력한 클래스 기반으로 인스턴스가 생상되었는지 True, False로 반환해줍니다.
#
# 예제 코드를 통해 확인해보겠습니다.

# %%
class Student:
    def __init__(self):
        pass

#Student()는 클래스 명과 동일한 생성자 함수
#student는 Student 클래스로 생성된 객체 즉 인스턴스를 말함
student = Student()

print("isinstance(student, Student):", isinstance(student, Student)) #인스턴스, 클래스
# Out:
# isinstance(student, Student): True

# %% [markdown]
# Student 클래스로 만든 클래스가 student이기 때문에 True가 출력된걸 확인할 수 있습니다.
#
# 지금부터는 isinstance() 함수를 이용해 여러개의 클래스에서 생성된 인스턴스를 구분해 처리하는 코드를 작성해보겠습니다.

# %%
class Python:
    def study(self):
        print("파이썬을 수강중입니다.")

class Java:
    def teach(self):
        print("자바를 수강중입니다.")

programming_subjects = [Python(), Python(), Python(), Java(), Python()]

for subject in programming_subjects:
    if isinstance(subject, Python):
        subject.study()
    elif isinstance(subject, Java):
        subject.teach()
# Out:
# 파이썬을 수강중입니다.
# 파이썬을 수강중입니다.
# 파이썬을 수강중입니다.
# 자바를 수강중입니다.
# 파이썬을 수강중입니다.

# %% [markdown]
# 대부분 객체 지향 프로그래밍은 모든 데이터를 클래스로 구현합니다.
#
# 이때 많은 데이터들을 리스트로 관리하면 굉장히 편합니다.
#
# 그리고 리스트에 들어있는 데이터마다 이렇게
# 다양한 처리를 할 수 있도록 코드를 작성해 놓으면 더 효율적인 데이터를 다룰 수 있다는 점을 알아두면 좋습니다.
#
# 다음으로 알아볼 내용은 특수한 이름의 메소드입니다.
#
# 앞서 만든 작성한 코드에서 생성된 student라는 인스턴스에 점(.)을 붙이면 자동완성 기능이 작동하며
#
# 어떤 메소드를 사용할 수 있는지 보여줍니다.
#
# ![특수 메소드.png](<attachment:특수 메소드.png>)

# %%
# 앞서 작성한 코드
class Student:
    def __init__(self):
        pass

#Student()는 클래스 명과 동일한 생성자 함수
#student는 Student 클래스로 생성된 객체 즉 인스턴스를 말함
student = Student()

student.

print("isinstance(student, Student):", isinstance(student, Student)) #인스턴스, 클래스

# %% [markdown]
# 우리가 만들지 않은것들이 굉장히 많이 보입니다.<br>
# 이러한 기능은 모두 파이썬이 클래스를 생성하면 기본적으로 제공해 주는 기능입니다.
#
# 이러한 기능의 메소드는 특이한 이름을 가지고 있습니다. <br>
# `__이름__` 이런 형태의 네이밍을 가집니다.
#
# ```__str__()```이란 이름으로 기존 to_string 함수의 이름을 대체 해보겠습니다.
#
# 참고로, ```__str__()```로 정의하게 되면 str()만 입력해도 기존 방식과 다르게 자동으로 호출됩니다.
#
# 그래서 기존에 있는 함수 호출 부분인 코드를
#
# ```
# print(student.to_string())
# ```
#
# 이렇게 변경해서 실행할 수 있습니다.
# ```
# print(str(student))
# ```

# %%
#기존 코드
# __ 은 언더바('_') 두개 입니다.
class CreateOzStudent:
    def __init__(self, name, python, database, django, AWS):#name, python 등은 식별자
        self.name = name#self가 가지고 있는 속성과 기능에 접근하는 방법 self.식별자
        self.python = python
        self.database = database
        self.django = django
        self.AWS = AWS

    def get_sum(self):
        return self.python + self.database + self.django + self.AWS
    
    def get_average(self):
        return self.get_sum() / 4
    
    def to_string(self):
        return f'{self.name}\t{self.get_sum()}\t{self.get_average()}'

#데이터 입력
oz_students = [
    CreateOzStudent("백현우",4 ,3 ,3 ,2),#CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
    CreateOzStudent("홍혜인",4 ,5 ,2 ,4),
    CreateOzStudent("윤은성",3 ,4 ,4 ,1),
    CreateOzStudent("홍수철",2 ,3 ,1 ,5)
]

print("이름", "총점", "평균", sep="\t")

for student in oz_students:
    print(student.to_string())

# %%
#__str__ 적용 코드
# __ 은 언더바('_') 두개 입니다.
class CreateOzStudent:
    def __init__(self, name, python, database, django, AWS):#name, python 등은 식별자
        self.name = name#self가 가지고 있는 속성과 기능에 접근하는 방법 self.식별자
        self.python = python
        self.database = database
        self.django = django
        self.AWS = AWS

    def get_sum(self):
        return self.python + self.database + self.django + self.AWS
    
    def get_average(self):
        return self.get_sum() / 4
    
    def __str__(self):
        return f'{self.name}\t{self.get_sum()}\t{self.get_average()}'

#데이터 입력
oz_students = [
    CreateOzStudent("백현우",4 ,3 ,3 ,2),#CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
    CreateOzStudent("홍혜인",4 ,5 ,2 ,4),
    CreateOzStudent("윤은성",3 ,4 ,4 ,1),
    CreateOzStudent("홍수철",2 ,3 ,1 ,5)
]

print("이름", "총점", "평균", sep="\t")

for student in oz_students:
    print(str(student))
# Out:
# 이름	총점	평균
# 백현우	12	3.0
# 홍혜인	15	3.75
# 윤은성	12	3.0
# 홍수철	11	2.75

# %% [markdown]
# ```__srt__``` 외에도 다양한 이름들이 있습니다.
#
# 예를 하나 더 들어보자면 ```__eq__```로 이름을 사용한 경우
#
# 실행 방법은 '==' 이용해서 사용할 수 있습니다.
#
# 특수 메소드까지 사용하는 경우는 그렇게 많지않기 때문에 그때그때 마다 자료를 찾아서 개발해보시기 바랍니다.

# %% [markdown]
# 오늘의 강의는 여기까지 입니다.
#
# 수강생 여러분 강의 듣느냐 수고많으셨습니다.
#
# 그럼 저는 다음 강의에서 여러분을 기다리고 있겠습니다.
